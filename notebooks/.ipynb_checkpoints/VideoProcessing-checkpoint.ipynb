# %%
from bs4 import BeautifulSoup
from urllib2 import urlopen, HTTPError, URLError
from urlparse import urlparse, urljoin
import os.path, errno
import shutil
import subprocess32 as subprocess
from concurrent.futures import *
from itertools import islice

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
cd ~/MEGA/eScienceWork/projects/OOIVideos/OOIVideos
# Out:
# /home/val/MEGA/eScienceWork/projects/OOIVideos/OOIVideos

# %%
ls
# Out:
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T000000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T030000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T060000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T090000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T120000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T180000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T210000Z.mp4
# opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_02_CAMHDA301-20160102T210000Z.mp4

# %%
gd_url = 'https://drive.google.com/folderview?id=0Bxkqjvq_AAi_bVU0bDFocFl0SG8&usp=sharing'

# %%
import imageio

# %%
filename = 'opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T210000Z.mp4'

# %%
vid = imageio.get_reader(filename,  'ffmpeg')
nums = [2760,8160,13200]
for num in nums:
    image = vid.get_data(num)
    plt.imshow(image)
    plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
image.shape
# Out:
# (1080, 1920, 3)

# %%
len(vid)
# Out:
# 25200

# %%
# Frames per second
25200/(14*60)
# Out:
# 30

# %%
# 7:20
(7*60+20)*30
# Out:
# 13200

# %%
# 4:32
(4*60+32)*30
# Out:
# 8160

# %%
#1:42
(1*60+32)*30
# Out:
# 2760

# %%
8160,8280
# Out:
# (8160, 8280)

# %%
np.arange(0,24,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21])

# %%
date = '2016_01_01'
import imageio
import time

# %% [markdown]
# ### Processing the boundary at 4:32

# %%
plt.figure()
fig = plt.gcf()
fig.show()
fig.canvas.draw()


frames = []
for i in np.arange(0,24,3):
    if i != 15:
        filename = 'opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T'+str(i).zfill(2)+'0000Z.mp4'
        vid = imageio.get_reader(filename,  'ffmpeg')
        # nums = [2760,8160,13200]
        num = 13200
        num = 8160
        #for num in nums:
        image = vid.get_data(num)
        frames.append(image)

    plt.imshow(image)
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ##### There is jitter! We will need to adjust for it if we are interested in the growth of the structure.

# %% [markdown]
# ##### But let's just look at the boundaries. Here is some rough extraction based on simple tresholding:

# %%
# from skimage import feature
# edges = feature.canny(frames[0][:,:,0], sigma=3)
from skimage.segmentation import find_boundaries

# %%
plt.figure()
fig = plt.gcf()
fig.show()
fig.canvas.draw()

for frame in frames:
    binary = frame[:,:,0]<50
    # plt.imshow(edges,cmap = 'gray')
    bdry = find_boundaries(binary, connectivity = 5)
    plt.imshow((1 - bdry)*frame[:,:,0], cmap = 'gray')
    fig.show()
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,...">

# %%
# TODO
# 1) plot in color
# 2) plot contours for boundaries
# 3) registration

# %%
# extract the dimensions
print('Number of frames: '+ str(len(frames)))
print('Image size: '+ str(frames[0].shape))
nofFrames = len(frames)
dim1  = frames[0].shape[0]
dim2 = frames[0].shape[1]
# Out:
# Number of frames: 7
# Image size: (1080, 1920, 3)

# %% [markdown]
# ### Processing slices at 7:20

# %%
plt.figure()
fig = plt.gcf()
fig.show()
fig.canvas.draw()


frames = []
for i in np.arange(0,24,3):
    if i != 15:
        filename = 'opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T'+str(i).zfill(2)+'0000Z.mp4'
        vid = imageio.get_reader(filename,  'ffmpeg')
        # nums = [2760,8160,13200]
        num = 13200
        image = vid.get_data(num)
        frames.append(image)

    plt.imshow(image)
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,...">

# %%
video = np.array(frames)

# %% [markdown]
# ### PCA Decomposition

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = nofFrames)

# %%
pca.fit(np.reshape(video,(nofFrames,dim1*dim2*3)))
# Out:
# PCA(copy=True, n_components=7, whiten=False)

# %%
pca.components_.shape
# Out:
# (7, 6220800)

# %%
modes = np.reshape(pca.components_,(nofFrames,dim1,dim2,3))

# %%
pca.components_.shape
# Out:
# (7, 6220800)

# %%
modes.shape
# Out:
# (7, 1080, 1920, 3)

# %%
plt.imshow((modes[0,:,:,2]+0.2)*255,cmap = 'gray')

# %%
for m in range(modes.shape[0]):
    plt.figure()
    plt.imshow((modes[m,:,:,2]),cmap = 'gray')
    plt.title('PCA Mode '+  str(m+1))
# Out:
# <div id='de78fbcb-0320-4c4e-97df-5e8ee40cd05f'></div>
# <div id='13a79fa4-978e-4c4d-a4f1-993cf54c8b66'></div>
# <div id='470d0dfb-5c4d-4422-919e-25cfbec2c61b'></div>
# <div id='31912e7e-5c6e-477d-8d27-c134609e3ecc'></div>
# <div id='752af015-b0b3-42d5-a461-0f074cdab944'></div>
# <div id='172f8166-b312-44b8-8d24-49e0fc22270c'></div>
# <div id='e6ae4f34-a9d0-4767-a565-2bdefe161496'></div>

# %%
np.min(modes)
# Out:
# -0.18045789825583641

# %%
np.min(modes[6,:])
# Out:
# -0.18045789825583641

# %%
np.max(modes[6,:,:,:])
# Out:
# 0.98152375923519963

# %%
np.max(modes[6])
# Out:
# 0.98152375923519963

# %% [markdown]
# ### Processing a specific video

# %%
# just reading sparse frames:
filename = 'opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T210000Z.mp4'

# %%
vid = imageio.get_reader(filename, 'ffmpeg')
# does it show a different length?
print(len(vid))
nums = np.arange(0,len(vid),100)
frames = []
values = []
im_prev = np.zeros((dim1,dim2,3))

fig = plt.figure()
fig.show()
fig.canvas.draw()

nums = list(np.arange(2000,3000,1))
for num in nums:
    im = vid.get_data(num)
    # plt.imshow(im)
    # plt.title('Image frame ' + str(num))
        
    # fig.show()
    #fig.canvas.draw()

#for i,im in enumerate(vid[3000:3100]):
    # plt.imshow(im)
    # plt.title('Image frame ' + str(i))
    # fig.show()
    # fig.canvas.draw()
    
     
    # values.append(np.sum(np.abs(im)))
    
    # store the absolute difference between the images
    diff = np.sum(np.abs(im - im_prev))
    im_prev = im
    frames.append(im)
    values.append(diff)
# Out:
# 25200
# <img src="data:image/png;base64,...">

# %%
# Out:
# 1000

# %%
plt.figure()
plt.plot(values)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# calculate deviation from moving average:
l = []
for i in range(1,len(frames) - 2):
    mean = (frames[i]+frames[i-1]+frames[i+1])/3.
    var = (np.sum(np.abs(frames[i]-mean)) + np.sum(np.abs(frames[i-1]-mean)) + np.sum(np.abs(frames[i+1]-mean)))/3.
    l.append(var)

# %% [markdown]
# #### OpenCV test

# %%
import cv2

# %%
#### Need to link to ffmpeg!!!!!

# %%
cap = cv2.VideoCapture("/home/val/MEGA/eScienceWork/projects/OOIVideos/OOIVideos/opendap_hyrax_large_format_RS03ASHS-PN03B-06-CAMHDA301_2016_01_01_CAMHDA301-20160101T210000Z.mp4")
cap.grab()

# %%
cap = cv2.VideoCapture(0)

# %%
print(cap.grab())
success,image = cap.read()
print(success)

# %%
#video.open()
video = []
success = 1
while success:
    success, image = cap.read()
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    video.append(gray)
    #cv2.imshow('frame',gray)

# %%
len(video)

# %%
success, image = cap.read()

# %%
print(success)

# %%
cap.isOpened()

# %%
plt.figure()
plt.imshow(gray)
plt.show()

# %%
print(len(values))
# plt.figure(figsize = (16,6))
plt.plot(np.array(values[1500:1880]))
plt.show()
# Out:
# 25200

# %%
# plt.imshow(frames[1250])

plt.figure()
fig = plt.gcf()
fig.show()
fig.canvas.draw()

for i in range(200):
    plt.imshow(vid.get_data(1500+i))
    plt.title(str(1500+i))
    fig.show()
    fig.canvas.draw()
    
    #plt.pause(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-73ebea0c0538> in <module>()
#       1 # plt.imshow(frames[1250])
#       2
# ----> 3 plt.figure()
#       4 fig = plt.gcf()
#       5 fig.show()
#
# NameError: name 'plt' is not defined

# %%
# for the flat regions: detect what is moving in the flat regions

# 1) create a mask based on a threshold of values
idx = (values>10000)
# for each chunk of ones: apply

# %%
len(vid)
# Out:
# 25200

# %%
video = np.aray(frames)
res = np.sum(np.abs(video[1:,:,:,:] -video[:video.shape[0]-1,:,:,:]))

# %% [markdown]
# ### Fetching More Movies

# %%
cd ~/MEGA/eScienceWork/projects/OOIVideos
# Out:
# /home/val/MEGA/eScienceWork/projects/OOIVideos

# %%
import sys
sys.path.append('~/MEGA/eScienceWork/projects/OOIVideos')

# %%
import fetchmovies as fm

# %%
url = "http://opendap-devel.ooi.rutgers.edu:8080/opendap/hyrax/large_format/RS03ASHS-PN03B-06-CAMHDA301/2016/catalog.xml"

mylist = fm.download(url,'test.mp4')
# Out:
# URL Error: [Errno 111] Connection refused http://opendap-devel.ooi.rutgers.edu:8080/opendap/hyrax/large_format/RS03ASHS-PN03B-06-CAMHDA301/2016/catalog.xml

# %%
for item in mylist:
    print item
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-9acc3b1f64d6> in <module>()
# ----> 1 for item in mylist:
#       2     print item
#
# TypeError: 'bool' object is not iterable

# %%
import imp
# imp.load_source('fm','fetchmovies.py')
import fetchmovies as fm
reload(fm)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-100-cd8ff2f24b2e> in <module>()
#       2 # imp.load_source('fm','fetchmovies.py')
#       3 import fetchmovies as fm
# ----> 4 reload(fm)
#
# ImportError: No module named fetchmovies
